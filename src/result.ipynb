# %% [markdown]
# # Results of Model 1 and 2
#
# * Model 1: Minimize transaction size
# * Model 2: Maximize number of selected UTXOs with an upper bound of size
#     * Model 2-1: $\gamma = 10\%$
#         * Model 2-1: $\gamma = 10\%$
#             * Model 2-1: $\gamma = 10\%$

# %%
import plot

# %% [markdown]
# ### Transaction Size

# %%
plot.plot_tx_size()

# %% [markdown]
# ### Number of Selected UTXOs

# %%
plot.plot_n_selected()

# %% [markdown]
# ### Average of Value of Selected Inputs

# %%
plot.plot_avg_utxo_val()

# %% [markdown]
# ### Standard Deviation of Value of Selected Inputs

# %%
plot.plot_sd_utxo_val()
